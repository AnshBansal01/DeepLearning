# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshBansal01/DeepLearning/blob/main/DL%20Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
Data=pd.read_csv(r'/content/drive/MyDrive/Deep Learning/Shopping Mall Customer Segmentation Data .csv')
Data.describe()

from skimage import io, filters
import matplotlib.pyplot as plt

image = io.imread('/content/drive/MyDrive/Deep Learning/png-transparent-car-mercedes-car-love-compact-car-vehicle.png', as_gray=True)

edges = filters.sobel(image)

plt.imshow(edges, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
